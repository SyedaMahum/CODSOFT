# %%
import pandas as pd 
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder
from sklearn.datasets import make_classification
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score
from sklearn.metrics import classification_report
from sklearn.ensemble import RandomForestClassifier
import warnings

# %%
df=pd.read_csv(r'C:\Users\Thinpad\Desktop\INTERNSHIP\credit card\creditcard.csv')

# %%
df
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# ...

# %%
#df.isna().sum()
#df['Class'].unique()
#rows1 = df[df['Class'] == 1]
#rows1

# %%
duplicates = df[df.duplicated()]
duplicates
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 33          26.0 -0.529912  0.873892  1.347247  0.145457  0.414209  0.100223
# 35          26.0 -0.535388  0.865268  1.351076  0.147575  0.433680  0.086983
# 113         74.0  1.038370  0.127486  0.184456  1.109950  0.441699  0.945283
# 114         74.0  1.038370  0.127486  0.184456  1.109950  0.441699  0.945283
# 115         74.0  1.038370  0.127486  0.184456  1.109950  0.441699  0.945283
# ...          ...       ...       ...       ...       ...       ...       ...
# 282987  171288.0  1.912550 -0.455240 -1.750654  0.454324  2.089130  4.160019
# 283483  171627.0 -1.464380  1.368119  0.815992 -0.601282 -0.689115 -0.487154
# 283485  171627.0 -1.457978  1.378203  0.811515 -0.603760 -0.711883 -0.471672
# 284191  172233.0 -2.667936  3.160505 -3.355984  1.007845 -0.377397 -0.109730
# 284193  172233.0 -2.691642  3.123168 -3.339407  1.017018 -0.293095 -0.167054
#
# ...

# %%
df = df.drop_duplicates()
df
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# ...

# %% [markdown]
# Standardization transforms your data to have a mean of 0 and a standard deviation of 1

# %%
from sklearn.preprocessing import MinMaxScaler

exclude = ['Class']

# Create a copy of the DataFrame with the columns to be normalized
df_norm = df.copy()

# Initialize the Min-Max scaler (you can use StandardScaler if needed)
scaler = MinMaxScaler()

# Normalize only the columns that are not in the exclusion list
col_norm = [col for col in df_norm.columns if col not in exclude]

df_norm[col_norm] = scaler.fit_transform(df_norm[col_norm])
df_norm
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 0       0.000000  0.935192  0.766490  0.881365  0.313023  0.763439  0.267669
# 1       0.000000  0.978542  0.770067  0.840298  0.271796  0.766120  0.262192
# 2       0.000006  0.935217  0.753118  0.868141  0.268766  0.762329  0.281122
# 3       0.000006  0.941878  0.765304  0.868484  0.213661  0.765647  0.275559
# 4       0.000012  0.938617  0.776520  0.864251  0.269796  0.762975  0.263984
# ...          ...       ...       ...       ...       ...       ...       ...
# 284802  0.999965  0.756448  0.873531  0.666991  0.160317  0.729603  0.236810
# 284803  0.999971  0.945845  0.766677  0.872678  0.219189  0.771561  0.273661
# 284804  0.999977  0.990905  0.764080  0.781102  0.227202  0.783425  0.293496
# 284805  0.999977  0.954209  0.772856  0.849587  0.282508  0.763172  0.269291
# 284806  1.000000  0.949232  0.765256  0.849601  0.229488  0.765632  0.256488
#
# ...

# %%
#rows = df_norm[df_norm['Class'] == 1]
#rows

# %% [markdown]
# for imbalance in dataset

# %%
pip install imbalanced-learn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from imblearn.over_sampling import SMOTE

# %%
X, y = make_classification(n_classes=2, class_sep=2, weights=[0.1, 0.9], n_informative=3, 
                           n_redundant=1, flip_y=0, n_features=20, 
                           n_clusters_per_class=1, n_samples=1000, 
                           random_state=10)

# %%
#X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=10)

# %%
smote = SMOTE(random_state=10)
X_train_resampled, y_train_resampled = smote.fit_resample(X_train, y_train)
print('Shape of X_train = ', X_train_resampled.shape)
print('Shape of y_train = ', y_train_resampled.shape)
print('Shape of X_test = ', X_test.shape)
print('Shape of y_test = ', y_test.shape)
# Out:
# Shape of X_train =  (424850, 30)
# Shape of y_train =  (424850,)
# Shape of X_test =  (70932, 30)
# Shape of y_test =  (70932,)

# %%
# df=df.drop("Id",axis=1)
X = df.drop("Class", axis = 1)
y = df["Class"]
print('Shape of X = ', X.shape)
print('Shape of y = ', y.shape)
# Out:
# Shape of X =  (283726, 30)
# Shape of y =  (283726,)

# %%
# Random Forest Classifier
rf_classifier = RandomForestClassifier(n_estimators=100, random_state=42,min_samples_split=6)

rf_classifier.fit(X_train_resampled, y_train_resampled)

y_pred = rf_classifier.predict(X_test)

class_report = classification_report(y_test, y_pred)
score = f1_score(y_test, y_pred,average='micro')*100

print("Classification Report:\n", class_report)
print("F1 Score: ", score)
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     70828
#            1       0.86      0.80      0.83       104
#
#     accuracy                           1.00     70932
#    macro avg       0.93      0.90      0.91     70932
# weighted avg       1.00      1.00      1.00     70932
#
# F1 Score:  99.95065696723623
